# %% [markdown]
# ### Building Dataset

# %%
import pandas as pd

# Defining data with function names, ratings, and other features including final score.
data = [
    {
        'Function_Name': 'find_most_frequent_elements',
        'Cyclomatic_Complexity': 2,
        'Function_Length': 4,
        'Number_of_Loops': 1,
        'Modularity': 9,  # out of 10
        'Comment_Quality': 7,  # out of 10
        'Naming_Quality': 8,  # out of 10
        'Final_Score': 8  # out of 10
    },
    {
        'Function_Name': 'do_thing',
        'Cyclomatic_Complexity': 4,
        'Function_Length': 6,
        'Number_of_Loops': 2,
        'Modularity': 3,  # out of 10
        'Comment_Quality': 0,  # out of 10
        'Naming_Quality': 3,  # out of 10
        'Final_Score': 2  # out of 10
    },
    {
        'Function_Name': 'reverse_string',
        'Cyclomatic_Complexity': 1,
        'Function_Length': 3,
        'Number_of_Loops': 1,
        'Modularity': 10,  # out of 10
        'Comment_Quality': 9,  # out of 10
        'Naming_Quality': 10,  # out of 10
        'Final_Score': 9  # out of 10
    },
    {
        'Function_Name': 'calculate_area',
        'Cyclomatic_Complexity': 2,
        'Function_Length': 5,
        'Number_of_Loops': 0,
        'Modularity': 9,  # out of 10
        'Comment_Quality': 6,  # out of 10
        'Naming_Quality': 7,  # out of 10
        'Final_Score': 7  # out of 10
    },
    {
        'Function_Name': 'sum_values',
        'Cyclomatic_Complexity': 1,
        'Function_Length': 2,
        'Number_of_Loops': 0,
        'Modularity': 10,  # out of 10
        'Comment_Quality': 8,  # out of 10
        'Naming_Quality': 9,  # out of 10
        'Final_Score': 8  # out of 10
    },
    {
        'Function_Name': 'find_duplicates',
        'Cyclomatic_Complexity': 3,
        'Function_Length': 7,
        'Number_of_Loops': 2,
        'Modularity': 4,  # out of 10
        'Comment_Quality': 3,  # out of 10
        'Naming_Quality': 5,  # out of 10
        'Final_Score': 4  # out of 10
    },
    {
        'Function_Name': 'generate_random_numbers',
        'Cyclomatic_Complexity': 1,
        'Function_Length': 5,
        'Number_of_Loops': 1,
        'Modularity': 8,  # out of 10
        'Comment_Quality': 7,  # out of 10
        'Naming_Quality': 9,  # out of 10
        'Final_Score': 8  # out of 10
    },
    {
        'Function_Name': 'filter_odd_numbers',
        'Cyclomatic_Complexity': 1,
        'Function_Length': 4,
        'Number_of_Loops': 1,
        'Modularity': 10,  # out of 10
        'Comment_Quality': 8,  # out of 10
        'Naming_Quality': 9,  # out of 10
        'Final_Score': 9  # out of 10
    },
    {
        'Function_Name': 'calculate_average',
        'Cyclomatic_Complexity': 2,
        'Function_Length': 5,
        'Number_of_Loops': 1,
        'Modularity': 9,  # out of 10
        'Comment_Quality': 7,  # out of 10
        'Naming_Quality': 8,  # out of 10
        'Final_Score': 8  # out of 10
    },
    {
        'Function_Name': 'extract_unique_elements',
        'Cyclomatic_Complexity': 1,
        'Function_Length': 4,
        'Number_of_Loops': 1,
        'Modularity': 10,  # out of 10
        'Comment_Quality': 6,  # out of 10
        'Naming_Quality': 9,  # out of 10
        'Final_Score': 8  # out of 10
    }
]

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('function_quality_scores.csv', index=False)

print("CSV file with Final Score created successfully!")
# Out:
# CSV file with Final Score created successfully!

# %%
new_data = [
    {'Function_Name': 'proc_data', 'Cyclomatic_Complexity': 4, 'Function_Length': 7, 'Number_of_Loops': 2, 
     'Modularity': 2, 'Comment_Quality': 2, 'Naming_Quality': 1, 'Final_Score': 2},
    {'Function_Name': 'aaa', 'Cyclomatic_Complexity': 3, 'Function_Length': 6, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 1, 'Naming_Quality': 0, 'Final_Score': 1},
    {'Function_Name': 'calc', 'Cyclomatic_Complexity': 5, 'Function_Length': 10, 'Number_of_Loops': 3, 
     'Modularity': 4, 'Comment_Quality': 1, 'Naming_Quality': 2, 'Final_Score': 3},
    {'Function_Name': 'work', 'Cyclomatic_Complexity': 6, 'Function_Length': 8, 'Number_of_Loops': 2, 
     'Modularity': 2, 'Comment_Quality': 0, 'Naming_Quality': 1, 'Final_Score': 1},
    {'Function_Name': 'do_stuff', 'Cyclomatic_Complexity': 3, 'Function_Length': 6, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 2, 'Naming_Quality': 2, 'Final_Score': 3},
    {'Function_Name': 'foo', 'Cyclomatic_Complexity': 2, 'Function_Length': 5, 'Number_of_Loops': 1, 
     'Modularity': 2, 'Comment_Quality': 1, 'Naming_Quality': 1, 'Final_Score': 2},
    {'Function_Name': 'xyz', 'Cyclomatic_Complexity': 4, 'Function_Length': 9, 'Number_of_Loops': 3, 
     'Modularity': 1, 'Comment_Quality': 0, 'Naming_Quality': 0, 'Final_Score': 1},
    {'Function_Name': 'function1', 'Cyclomatic_Complexity': 4, 'Function_Length': 6, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 2, 'Naming_Quality': 2, 'Final_Score': 3},
    {'Function_Name': 'method_a', 'Cyclomatic_Complexity': 3, 'Function_Length': 7, 'Number_of_Loops': 2, 
     'Modularity': 2, 'Comment_Quality': 1, 'Naming_Quality': 0, 'Final_Score': 1},
    {'Function_Name': 'func', 'Cyclomatic_Complexity': 2, 'Function_Length': 4, 'Number_of_Loops': 1, 
     'Modularity': 2, 'Comment_Quality': 0, 'Naming_Quality': 1, 'Final_Score': 1}
]

# Convert the new data into a DataFrame
df_new = pd.DataFrame(new_data)

# Append the new data to the CSV file (without writing the header again)
df_new.to_csv('function_quality_scores.csv', mode='a', header=False, index=False)

print("New records added to the existing CSV file successfully.")
# Out:
# New records added to the existing CSV file successfully.

# %%
new_data = [
    {'Function_Name': 'process_data', 'Cyclomatic_Complexity': 10, 'Function_Length': 8, 'Number_of_Loops': 3, 
     'Modularity': 2, 'Comment_Quality': 0, 'Naming_Quality': 5, 'Final_Score': 3},
    {'Function_Name': 'find_pairs', 'Cyclomatic_Complexity': 6, 'Function_Length': 6, 'Number_of_Loops': 2, 
     'Modularity': 2, 'Comment_Quality': 0, 'Naming_Quality': 6, 'Final_Score': 3},
    {'Function_Name': 'calculate_sums', 'Cyclomatic_Complexity': 5, 'Function_Length': 6, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 0, 'Naming_Quality': 7, 'Final_Score': 3},
    {'Function_Name': 'process_numbers', 'Cyclomatic_Complexity': 9, 'Function_Length': 8, 'Number_of_Loops': 3, 
     'Modularity': 2, 'Comment_Quality': 0, 'Naming_Quality': 4, 'Final_Score': 2},
    {'Function_Name': 'analyze_data', 'Cyclomatic_Complexity': 5, 'Function_Length': 6, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 0, 'Naming_Quality': 4, 'Final_Score': 3},
    {'Function_Name': 'compute_values', 'Cyclomatic_Complexity': 10, 'Function_Length': 9, 'Number_of_Loops': 3, 
     'Modularity': 2, 'Comment_Quality': 0, 'Naming_Quality': 4, 'Final_Score': 2},
    {'Function_Name': 'max_min_values', 'Cyclomatic_Complexity': 6, 'Function_Length': 6, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 0, 'Naming_Quality': 5, 'Final_Score': 3},
    {'Function_Name': 'count_duplicates', 'Cyclomatic_Complexity': 6, 'Function_Length': 6, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 0, 'Naming_Quality': 6, 'Final_Score': 3},
    {'Function_Name': 'fibonacci', 'Cyclomatic_Complexity': 7, 'Function_Length': 7, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 0, 'Naming_Quality': 6, 'Final_Score': 3},
    {'Function_Name': 'generate_sequence', 'Cyclomatic_Complexity': 10, 'Function_Length': 8, 'Number_of_Loops': 3, 
     'Modularity': 2, 'Comment_Quality': 0, 'Naming_Quality': 5, 'Final_Score': 2}
]

# Convert the new data into a DataFrame
df_new = pd.DataFrame(new_data)

# Append the new data to the CSV file (without writing the header again)
df_new.to_csv('function_quality_scores.csv', mode='a', header=False, index=False)

print("New records added to the existing CSV file successfully.")
# Out:
# New records added to the existing CSV file successfully.

# %%
new_data = [
    {'Function_Name': 'calculate_average_grades', 'Cyclomatic_Complexity': 8, 'Function_Length': 7, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 9, 'Final_Score': 9},
    {'Function_Name': 'find_unique_elements', 'Cyclomatic_Complexity': 5, 'Function_Length': 5, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 8, 'Naming_Quality': 9, 'Final_Score': 8},
    {'Function_Name': 'merge_sorted_lists', 'Cyclomatic_Complexity': 6, 'Function_Length': 7, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 10, 'Naming_Quality': 10, 'Final_Score': 9.5},
    {'Function_Name': 'filter_and_sum_numbers', 'Cyclomatic_Complexity': 4, 'Function_Length': 4, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 9, 'Final_Score': 8.5},
    {'Function_Name': 'count_vowels_in_strings', 'Cyclomatic_Complexity': 6, 'Function_Length': 6, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 10, 'Final_Score': 9},
    {'Function_Name': 'is_palindrome', 'Cyclomatic_Complexity': 3, 'Function_Length': 4, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 9, 'Final_Score': 9},
    {'Function_Name': 'calculate_salary', 'Cyclomatic_Complexity': 4, 'Function_Length': 6, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 9, 'Final_Score': 9},
    {'Function_Name': 'get_max_difference', 'Cyclomatic_Complexity': 5, 'Function_Length': 5, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 9, 'Final_Score': 9},
    {'Function_Name': 'generate_prime_numbers', 'Cyclomatic_Complexity': 8, 'Function_Length': 7, 'Number_of_Loops': 2, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 10, 'Final_Score': 9.5},
    {'Function_Name': 'fibonacci_series', 'Cyclomatic_Complexity': 5, 'Function_Length': 6, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 9, 'Final_Score': 9},
]
# Convert the new data into a DataFrame
df_new = pd.DataFrame(new_data)

# Append the new data to the CSV file (without writing the header again)
df_new.to_csv('function_quality_scores.csv', mode='a', header=False, index=False)

print("New records added to the existing CSV file successfully.")
# Out:
# New records added to the existing CSV file successfully.

# %%
new_data = [
    {'Function_Name': 'calc_salary', 'Cyclomatic_Complexity': 3, 'Function_Length': 3, 'Number_of_Loops': 1, 
     'Modularity': 2, 'Comment_Quality': 6, 'Naming_Quality': 6, 'Final_Score': 6},
    {'Function_Name': 'get_top_students', 'Cyclomatic_Complexity': 4, 'Function_Length': 5, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 8, 'Naming_Quality': 7, 'Final_Score': 8},
    {'Function_Name': 'handle_user_input', 'Cyclomatic_Complexity': 5, 'Function_Length': 6, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 7, 'Naming_Quality': 8, 'Final_Score': 7},
    {'Function_Name': 'get_age_from_dob', 'Cyclomatic_Complexity': 2, 'Function_Length': 4, 'Number_of_Loops': 0, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 9, 'Final_Score': 9},
    {'Function_Name': 'get_max_value', 'Cyclomatic_Complexity': 3, 'Function_Length': 4, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 5, 'Naming_Quality': 6, 'Final_Score': 5},
    {'Function_Name': 'check_prime', 'Cyclomatic_Complexity': 4, 'Function_Length': 5, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 8, 'Naming_Quality': 7, 'Final_Score': 8},
    {'Function_Name': 'calculate_area', 'Cyclomatic_Complexity': 3, 'Function_Length': 3, 'Number_of_Loops': 0, 
     'Modularity': 2, 'Comment_Quality': 9, 'Naming_Quality': 8, 'Final_Score': 9},
    {'Function_Name': 'merge_lists', 'Cyclomatic_Complexity': 4, 'Function_Length': 6, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 7, 'Naming_Quality': 7, 'Final_Score': 7},
    {'Function_Name': 'reverse_string', 'Cyclomatic_Complexity': 3, 'Function_Length': 4, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 9, 'Naming_Quality': 9, 'Final_Score': 9},
    {'Function_Name': 'sort_items', 'Cyclomatic_Complexity': 3, 'Function_Length': 5, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 6, 'Naming_Quality': 7, 'Final_Score': 7},
    {'Function_Name': 'idka', 'Cyclomatic_Complexity': 3, 'Function_Length': 8, 'Number_of_Loops': 1, 
     'Modularity': 3, 'Comment_Quality': 0, 'Naming_Quality': 0, 'Final_Score': 1},
    {'Function_Name': 'calcsolve', 'Cyclomatic_Complexity': 5, 'Function_Length': 10, 'Number_of_Loops': 3, 
     'Modularity': 4, 'Comment_Quality': 1, 'Naming_Quality': 3, 'Final_Score': 2},
    {'Function_Name': 'work', 'Cyclomatic_Complexity': 8, 'Function_Length': 8, 'Number_of_Loops': 2, 
     'Modularity': 1, 'Comment_Quality': 0, 'Naming_Quality': 1, 'Final_Score': 0.5},
    {'Function_Name': 'do', 'Cyclomatic_Complexity': 3, 'Function_Length': 8, 'Number_of_Loops': 5, 
     'Modularity': 3, 'Comment_Quality': 1, 'Naming_Quality': 0, 'Final_Score': 1.5},
    {'Function_Name': 'solvenumber', 'Cyclomatic_Complexity': 2, 'Function_Length': 5, 'Number_of_Loops': 1, 
     'Modularity': 2, 'Comment_Quality': 6, 'Naming_Quality': 3, 'Final_Score': 2.5},
    {'Function_Name': 'xyzabc', 'Cyclomatic_Complexity': 4, 'Function_Length': 9, 'Number_of_Loops': 3, 
     'Modularity': 1, 'Comment_Quality': 8, 'Naming_Quality': 0, 'Final_Score': 4.5},
    {'Function_Name': 'greet', 'Cyclomatic_Complexity': 1, 'Function_Length': 3, 'Number_of_Loops': 0, 
     'Modularity': 3, 'Comment_Quality': 1, 'Naming_Quality': 6, 'Final_Score': 4},
    {'Function_Name': 'methods', 'Cyclomatic_Complexity': 3, 'Function_Length': 4, 'Number_of_Loops': 2, 
     'Modularity': 2, 'Comment_Quality': 1, 'Naming_Quality': 1, 'Final_Score': 1.5},
    
]
# Convert the new data into a DataFrame
df_new = pd.DataFrame(new_data)

# Append the new data to the CSV file (without writing the header again)
df_new.to_csv('function_quality_scores.csv', mode='a', header=False, index=False)

print("New records added to the existing CSV file successfully.")
# Out:
# New records added to the existing CSV file successfully.
